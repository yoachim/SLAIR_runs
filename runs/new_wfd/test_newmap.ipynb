# %%
import healpy as hp
import numpy as np
import matplotlib.pylab as plt
# %matplotlib inline
from gen_new_map import generate_goal

# %%
nside=32
ack=generate_goal(nside)
for key in ack:
    hp.mollview(ack[key], title=key)

# %%
# area of wfd
hp.nside2pixarea(nside, degrees=True)*np.where(ack['r'] == 1)[0].size
# Out:
# 18259.672545214144

# %%
np.unique(ack['r'])
# Out:
# array([ 0. ,  0.2,  1. ])
